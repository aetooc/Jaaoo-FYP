# %%
import requests

# %%
def get_geo_id(location, headers):
    url = "https://tripadvisor16.p.rapidapi.com/api/v1/hotels/searchLocation"
    querystring = {"query": location}
    response = requests.get(url, headers=headers, params=querystring)
    geo_data = response.json()
    if 'data' in geo_data and len(geo_data['data']) > 0:
        # Return the first geoId found
        return geo_data['data'][0]['geoId']
    else:
        # Return None if no geoId is found
        return None

# %%
def get_hotels(geo_id, checkIn, checkOut, adults, rooms, rating, priceMin, priceMax, headers):
    url = "https://tripadvisor16.p.rapidapi.com/api/v1/hotels/searchHotels"
    querystring = {"geoId":geo_id,"checkIn":checkIn,"checkOut":checkOut,"pageNumber":"1","adults":adults,"rooms":rooms,"currencyCode":"USD","rating":rating,"priceMin":priceMin,"priceMax":priceMax}
    response = requests.get(url, headers=headers, params=querystring)
    return response.json()

# %%
    # Assuming the headers, checkIn, checkOut, adults, rooms, rating, priceMin, priceMax are defined earlier in your code.

    all_hotels_info_str = ""  # This will accumulate hotel information for all locations
    locations = ["karachi", "london"]
    geoid = [295414,186338]

    headers = {
        "X-RapidAPI-Key": "113d7438a6mshacaef04c4c874adp1a822bjsn6549eef3a781",
        "X-RapidAPI-Host": "tripadvisor16.p.rapidapi.com"
    }

    j = 0
    for location in locations:
        # Task 1: Get geoId for the location
        # geo_id = get_geo_id(location, headers)
        geo_id = geoid[j]
        j=1
        if not geo_id:
            print(f"Failed to get GeoId for {location}.")
            continue
        
        print(f"GeoId for {location}: {geo_id}")
        hotel_data = get_hotels(geo_id, checkIn, checkOut, adults, rooms, rating, priceMin, priceMax, headers)

        if not (hotel_data and hotel_data.get('data', {}).get('data')):
            print(f"No hotel data found for {location}.")
            continue

        hotels = hotel_data['data']['data'][:5]

        hotels_info = [{
            'id': hotel['id'],
            'title': hotel['title'],
            'primaryInfo': hotel['primaryInfo'],
            'bubbleRating': hotel.get('bubbleRating', {}).get('rating', 'N/A'),
            'priceForDisplay': hotel.get('priceForDisplay', 'N/A'),
            'priceDetails': hotel.get('priceDetails', 'N/A')
        } for hotel in hotels]
        
        hotel_info_str = f"Hotels in {location}:\n"  # Add location name to the string
        for hotel in hotels_info:
            hotel_info_str += f"Hotel ID: {hotel['id']}\n"
            hotel_info_str += f"Title: {hotel['title']}\n"
            hotel_info_str += f"Primary Info: {hotel['primaryInfo']}\n"
            hotel_info_str += f"Bubble Rating: {hotel['bubbleRating']}\n"
            hotel_info_str += f"Price for Display: {hotel['priceForDisplay']}\n"
            hotel_info_str += f"Pricing Details: {hotel['priceDetails']}\n\n"

        all_hotels_info_str += hotel_info_str + "\n\n"
    print(all_hotels_info_str)
    all_hotels_info_str,hotel_info_str = None, None
# Out:
# GeoId for karachi: 295414
# GeoId for london: 186338
# Hotels in karachi:
# Hotel ID: 25168636
# Title: 1. Welcome Guest House
# Primary Info: None
# Bubble Rating: None
# Price for Display: $18
# Pricing Details: None
#
# Hotel ID: 17518689
# Title: 2. Dream Palace Guest House Karachi
# Primary Info: None
# Bubble Rating: None
# Price for Display: $10
# Pricing Details: Reserve now, pay at stay
#
# Hotel ID: 8636381
# Title: 3. Kingston Motel
# Primary Info: None
# Bubble Rating: None
# Price for Display: $16
# Pricing Details: None
#
# Hotel ID: 23326438
# Title: 4. Stay Inn Guest House
# Primary Info: None
# Bubble Rating: None
# Price for Display: $12
# Pricing Details: Reserve now, pay at stay
#
# Hotel ID: 24912400
# Title: 5. Waypoint Hotel
# Primary Info: None
# Bubble Rating: None
# Price for Display: $44
# Pricing Details: Reserve now, pay at stay
#
#
#
# Hotels in london:
# Hotel ID: 1019217
# Title: 1. Central Park Hotel
# Primary Info: Free breakfast included
# ...

# %%
hotels = [{'id': '1019217',
  'title': '1. Central Park Hotel',
  'primaryInfo': 'Free breakfast included',
  'secondaryInfo': None,
  'badge': {},
  'bubbleRating': {'count': '814', 'rating': 2.5},
  'isSponsored': False,
  'accentedLabel': False,
  'provider': 'Booking.com',
  'priceForDisplay': '$2,548',
  'strikethroughPrice': None,
  'priceDetails': 'Reserve now, pay at stay',
  'priceSummary': None,
  'cardPhotos': [{'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 1333,
     'maxWidth': 2000,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/0c/73/be/central-park-hotel.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 1333,
     'maxWidth': 2000,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/0c/74/ab/central-park-hotel.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 1333,
     'maxWidth': 2000,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/0c/73/54/central-park-hotel.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 1333,
     'maxWidth': 2000,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/0c/75/10/central-park-hotel.jpg?w={width}&h={height}&s=1'}}],
  'commerceInfo': {'externalUrl': 'https://www.tripadvisor.in/Commerce?p=BookingCom&src=257820692&geo=1019217&from=HotelDateSearch_Hotels&slot=1&matchID=1&oos=0&cnt=5&silo=10476&bucket=902999&nrank=1&crank=1&clt=M&ttype=MobileCR&tm=290523420&managed=false&capped=false&gosox=byOkEKV9uZATnjOHyPJQ1p4bL_9DTrzST7rrKrOV7TK_VF0E3Mt3xkOo8ERkomEhhK-sQiD8FdCofkGm5QTCQNKCS6eSMrn0vgKr8IUnQfrq3W4hFO8IiSlPUqk_hl5gEJOgmoHjxIHiCzIUdhaEGqUsRxpQLwFSBskT47TdFjYJnO5KTBdJLox3TJ2rhEpxW8km6jZhafJFWPdkWEzm1jOB80_lHOGc8OGAaFBacikMAnSPrQul2lS7Ylkk63KyTExIUvYkRdCFKothoVZZIEaJ4GRQ2YV93fS_XE3QGe4&priceShown=2548&pm=AIWE&hac=AVAILABLE&mbl=BEAT&mbldelta=0&rq=P&rate=2123.2500&fees=424.6500&cur=USD&adults=1&child_rm_ages=&inDay=18&outDay=19&rdex=RDEX_3b6a3df2c231145e5406509851dd48d0&rooms=1&inMonth=3&inYear=2024&outMonth=3&outYear=2024&auid=c814e083-fe9e-40a6-8454-63843b6685b1&def_d=true&bld=L_1,D_2,G_1,W_1,U_1,C_240318,T_18&bh=true&uf=T_0~P_2000,100000&cs=1e009ff8848972b9c2197a660a14fa335&ik=1847d4b669fd4a9ca0cd5394d3feeecc&aok=b818dadcd45c40a58d9445dfe7a9eacf&tp=APS-Hotels&pageLocId=186338',
   'provider': 'Booking.com',
   'loadingMessage': None,
   'priceForDisplay': {'text': '$2,548', 'debugValueKey': None},
   'strikethroughPrice': None,
   'pricingPeriod': None,
   'details': {'text': 'Reserve now, pay at stay'},
   'commerceSummary': None,
   'roomUrgencyMessage': None,
   'labels': []}},
 {'id': '22844369',
  'title': '2. US Embassy Riverside Apartment',
  'primaryInfo': None,
  'secondaryInfo': None,
  'badge': {},
  'bubbleRating': {'count': None, 'rating': None},
  'isSponsored': False,
  'accentedLabel': False,
  'provider': 'Booking.com',
  'priceForDisplay': '$3,440',
  'strikethroughPrice': '$3,693',
  'priceDetails': 'Reserve now, pay at stay',
  'priceSummary': None,
  'cardPhotos': [{'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/f5/02/c1/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/f5/02/b3/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/f5/02/a6/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/f5/02/9b/caption.jpg?w={width}&h={height}&s=1'}}],
  'commerceInfo': {'externalUrl': 'https://www.tripadvisor.in/Commerce?p=BookingCom&src=178928917&geo=22844369&from=HotelDateSearch_Hotels&slot=1&matchID=1&oos=0&cnt=2&silo=10476&bucket=902999&nrank=1&crank=1&clt=M&ttype=MobileCR&tm=290523420&managed=false&capped=false&gosox=GiqwV7GV9kjPCcPasFS0-p4bL_9DTrzST7rrKrOV7TJXWMsB7fRDPq4KpXE7boqBa-awXjbLJ2xoUCLEnLmldoga9sE9kHj69A9O43F-mpvq3W4hFO8IiSlPUqk_hl5gRDCkwu1hujxaPaBrT-NyoqF3VFkR14Cfun2LXOzSjz41caKJIINH__TjoA67I6ILVBz-yx_o5ZKnVf3kXuAT9elTlo1lFnNUcqvtHvEG6hjQC0H0KEEYz4jkKNCLQUW6fCYjl5GR7KvglDymEV2vgA&priceShown=3440&pm=AIWE&hac=AVAILABLE&mbl=BEAT&mbldelta=0&rq=ML&rate=2866.3900&fees=828.0700&cur=USD&adults=1&child_rm_ages=&inDay=18&outDay=19&rdex=RDEX_1bfe2be4295851522875bc9bd20e797b&rooms=1&inMonth=3&inYear=2024&outMonth=3&outYear=2024&auid=2cb145e6-24f9-49ff-92a4-242b392575bb&def_d=true&bld=L_1,D_2,G_1,W_1,U_1,C_240318,T_18&bh=true&uf=T_0~P_2000,100000&cs=1c1b99df9fb3143ecbaee3011454ea29d&ik=1847d4b669fd4a9ca0cd5394d3feeecc&aok=92e340d9d8144bf9afd86149bd6ae973&tp=APS-Hotels&pageLocId=186338',
   'provider': 'Booking.com',
   'loadingMessage': None,
   'priceForDisplay': {'text': '$3,440', 'debugValueKey': None},
   'strikethroughPrice': {'text': '$3,693'},
   'pricingPeriod': None,
   'details': {'text': 'Reserve now, pay at stay'},
   'commerceSummary': None,
   'roomUrgencyMessage': None,
   'labels': []}},
 {'id': '22840673',
  'title': '3. SIAC Paddington Marble Arch',
  'primaryInfo': None,
  'secondaryInfo': None,
  'badge': {},
  'bubbleRating': {'count': None, 'rating': None},
  'isSponsored': False,
  'accentedLabel': '10% LESS THAN USUAL',
  'provider': 'Booking.com',
  'priceForDisplay': '$2,293',
  'strikethroughPrice': None,
  'priceDetails': 'Reserve now, pay at stay',
  'priceSummary': None,
  'cardPhotos': [{'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2b/91/2c/53/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2b/91/2c/55/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2b/91/2c/56/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2b/91/2c/52/caption.jpg?w={width}&h={height}&s=1'}}],
  'commerceInfo': {'externalUrl': 'https://www.tripadvisor.in/Commerce?p=BookingCom&src=150938737&geo=22840673&from=HotelDateSearch_Hotels&slot=1&matchID=1&oos=0&cnt=2&silo=10476&bucket=902999&nrank=1&crank=1&clt=M&ttype=MobileCR&tm=290523420&managed=false&capped=false&gosox=NXX4OBFECSbsrpXd8rz6-0aZc6yDEvv7x4Bxp5gZ9v8sEKa4ztf8fewTykkNVM9lP7deXxt7Tq398tl3gWOVcdLXakA5uP-_IXTj8pH8K-IQo9WeE8w-XwCNVuDtkqfV7ntRCIatisP0P4bk_pdWvAZXgxUrqEyezd9YBodrPmZBUrRmT7IYb0LxhX1NSxFlsgerALFvpRtC0G_Q6mNJ4zOB80_lHOGc8OGAaFBacikMAnSPrQul2lS7Ylkk63KyTExIUvYkRdCFKothoVZZIEaJ4GRQ2YV93fS_XE3QGe4&priceShown=2293&pm=AIWE&hac=AVAILABLE&mbl=MEET&mbldelta=100&rq=P&rate=1910.9300&fees=382.1900&cur=USD&adults=1&child_rm_ages=&inDay=18&outDay=19&rdex=RDEX_6258bc9b4abebf6684e6a8788c37c60&rooms=1&inMonth=3&inYear=2024&outMonth=3&outYear=2024&auid=ef2d2ece-dc80-498e-b09f-ee730d13b933&def_d=true&bld=L_1,D_2,G_1,W_1,U_1,C_240318,T_18&bh=true&uf=T_0~P_2000,100000&cs=1505a96260ab911bbfc927ee8bd72f7de&ik=1847d4b669fd4a9ca0cd5394d3feeecc&aok=bb7d8f258f7e4e058c2af42477c873c7&tp=APS-Hotels&pageLocId=186338',
   'provider': 'Booking.com',
   'loadingMessage': None,
   'priceForDisplay': {'text': '$2,293', 'debugValueKey': None},
   'strikethroughPrice': None,
   'pricingPeriod': None,
   'details': {'text': 'Reserve now, pay at stay'},
   'commerceSummary': None,
   'roomUrgencyMessage': None,
   'labels': []}},
 {'id': '25197434',
  'title': '4. Guest House Ellipse - Finchley',
  'primaryInfo': None,
  'secondaryInfo': None,
  'badge': {},
  'bubbleRating': {'count': None, 'rating': None},
  'isSponsored': False,
  'accentedLabel': '14% LESS THAN USUAL',
  'provider': 'Booking.com',
  'priceForDisplay': '$83',
  'strikethroughPrice': None,
  'priceDetails': None,
  'priceSummary': None,
  'cardPhotos': [{'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/29/30/e2/5b/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/29/41/42/07/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/29/3b/2c/f3/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/29/30/e2/5a/caption.jpg?w={width}&h={height}&s=1'}}],
  'commerceInfo': {'externalUrl': 'https://www.tripadvisor.in/Commerce?p=BookingCom&src=219487791&geo=25197434&from=HotelDateSearch_Hotels&slot=1&matchID=1&oos=0&cnt=2&silo=10476&bucket=902999&nrank=2&crank=2&clt=M&ttype=MobileCR&tm=290523420&managed=false&capped=false&gosox=4Kc6HTLPlsrAft81t3SeRZ4bL_9DTrzST7rrKrOV7TJXWMsB7fRDPq4KpXE7boqBM2VeTAWn07bVJbOU7amLzsJ8tVfwP1R2PlyETSwX0cbq3W4hFO8IiSlPUqk_hl5gEVf1m3HBwbihsE_vzs7pN4QAHe_9jTJtnMCC5orGWSp9iCRipwDYmRM65jK1OpIVGxR1v_3lC5x9xfEdCf1Z9VMVdBHvwbb8bIGhi6avBtFtzE7fEvx87uojNSyyr8H9HEdshLmobNZOJ8AXKJnTqdCv6zKRuQu9Lik_qs8WW5w&priceShown=83&pm=AIWE&hac=AVAILABLE&mbl=BEAT&mbldelta=0&rq=ML&rate=69.5000&fees=13.9000&cur=USD&adults=1&child_rm_ages=&inDay=18&outDay=19&rdex=RDEX_41a3f64cc029e31eb927b3715839ca89&rooms=1&inMonth=3&inYear=2024&outMonth=3&outYear=2024&auid=85aead26-052f-450f-b160-b2acfc29f7b7&def_d=true&bld=L_1,D_2,G_1,W_1,U_1,C_240318,T_18&bh=true&uf=T_0~P_2000,100000&cs=136e3c46ba41e6725117b7607c5555ef6&ik=1847d4b669fd4a9ca0cd5394d3feeecc&aok=e04518bfed0c467aa16e8ebc32681ddb&tp=APS-Hotels&pageLocId=186338',
   'provider': 'Booking.com',
   'loadingMessage': None,
   'priceForDisplay': {'text': '$83', 'debugValueKey': None},
   'strikethroughPrice': None,
   'pricingPeriod': None,
   'details': None,
   'commerceSummary': None,
   'roomUrgencyMessage': None,
   'labels': []}},
 {'id': '21400529',
  'title': '5. Urban Stay Oxford Gardens Apartments',
  'primaryInfo': None,
  'secondaryInfo': None,
  'badge': {},
  'bubbleRating': {'count': None, 'rating': None},
  'isSponsored': False,
  'accentedLabel': False,
  'provider': 'Booking.com',
  'priceForDisplay': '$257',
  'strikethroughPrice': '$340',
  'priceDetails': None,
  'priceSummary': None,
  'cardPhotos': [{'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/15/41/62/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2b/6f/3b/8e/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/29/2c/7c/53/caption.jpg?w={width}&h={height}&s=1'}},
   {'__typename': 'AppPresentation_PhotoItem',
    'sizes': {'__typename': 'AppPresentation_PhotoItemSizeDynamic',
     'maxHeight': 460,
     'maxWidth': 840,
     'urlTemplate': 'https://dynamic-media-cdn.tripadvisor.com/media/partner/bookingcom/photo-o/2a/bf/8e/26/caption.jpg?w={width}&h={height}&s=1'}}],
  'commerceInfo': {'externalUrl': 'https://www.tripadvisor.in/Commerce?p=BookingCom&src=139405118&geo=21400529&from=HotelDateSearch_Hotels&slot=1&matchID=1&oos=0&cnt=2&silo=10476&bucket=902999&nrank=1&crank=1&clt=M&ttype=MobileCR&tm=290523420&managed=false&capped=false&gosox=LdBOEtQLt-UVZXgDn7i0EZ4bL_9DTrzST7rrKrOV7TKVqAEAbF9zraSHnnOJ40tmjvde7976IymIqiJv14BBQHpJ7na9InW63TrmTUsQd8zq3W4hFO8IiSlPUqk_hl5gW_ML-XWennToi7rQUKKMfCZT4n6Dqj9LRYB0RSdt__x8Ba74Q0C8fNG2BrTeIXSbaq82LC7rNp2i-Bh99_cjjFMVdBHvwbb8bIGhi6avBtFtzE7fEvx87uojNSyyr8H9HEdshLmobNZOJ8AXKJnTqdCv6zKRuQu9Lik_qs8WW5w&priceShown=257&pm=AIWE&hac=AVAILABLE&mbl=BEAT&mbldelta=0&rq=ML&rate=214.0200&fees=125.6100&cur=USD&adults=1&child_rm_ages=&inDay=18&outDay=19&rdex=RDEX_5a5198ee5783a8add0b85d2befa2443d&rooms=1&inMonth=3&inYear=2024&outMonth=3&outYear=2024&auid=903d030f-f772-4dfa-99e4-cec836bb533e&def_d=true&bld=L_1,D_2,G_1,W_1,U_1,C_240318,T_18&bh=true&uf=T_0~P_2000,100000&cs=17b4f331a3462fd77226f5352639149f4&ik=1847d4b669fd4a9ca0cd5394d3feeecc&aok=d74485daf2d64a818f42a8192a6e93cc&tp=APS-Hotels&pageLocId=186338',
   'provider': 'Booking.com',
   'loadingMessage': None,
   'priceForDisplay': {'text': '$257', 'debugValueKey': None},
   'strikethroughPrice': {'text': '$340'},
   'pricingPeriod': None,
   'details': None,
   'commerceSummary': None,
   'roomUrgencyMessage': None,
   'labels': []}}]

# %%
hotel_info
# Out:
# {'id': '21400529',
#  'title': '5. Urban Stay Oxford Gardens Apartments',
#  'primaryInfo': None,
#  'bubbleRating': None,
#  'priceForDisplay': '$257',
#  'priceDetails': None}

# %%
        hotels_info = [{
            'id': hotel['id'],
            'title': hotel['title'],
            'primaryInfo': hotel['primaryInfo'],
            'bubbleRating': hotel.get('bubbleRating', {}).get('rating', 'N/A'),
            'priceForDisplay': hotel.get('priceForDisplay', 'N/A'),
            'priceDetails': hotel.get('priceDetails', 'N/A')
        } for hotel in hotels]

# %%
    all_hotels_info_str,hotel_info_str = None, None
